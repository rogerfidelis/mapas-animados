# %%
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine, text
from geoalchemy2 import Geometry
from gerar_mapa import BASE


# ============================================================
# CONFIGURAÇÕES
# ============================================================

ARQUIVO = (
    BASE.parent
    / "shapefiles"
    / "CAMPOS_PRODUCAO_SIRGAS"
    / "CAMPOS_PRODUCAO_SIRGASPolygon.shp"
)

SCHEMA = "core"
TABELA = "campos"

CRS_ESPERADO = "EPSG:4674"


# ============================================================
# CONEXÃO COM POSTGRESQL
# ============================================================

engine = create_engine(
    "postgresql+psycopg2://postgres:!Ademanda1456!@localhost:5432/ofi"
)


# ============================================================
# 1. LEITURA DO SHAPEFILE
# ============================================================

print("\n" + "=" * 60)
print("IMPORTAÇÃO DE CAMPOS DE PETRÓLEO")
print("=" * 60)

print("\nLendo shapefile...")

gdf = gpd.read_file(ARQUIVO)

print(f"Arquivo: {ARQUIVO}")
print(f"Registros encontrados: {len(gdf)}")
print(f"CRS encontrado: {gdf.crs}")


# ============================================================
# 2. VALIDAR CRS
# ============================================================

if gdf.crs is None:
    raise ValueError(
        "O shapefile não possui CRS definido."
    )

if gdf.crs.to_epsg() != 4674:
    raise ValueError(
        f"CRS inesperado: {gdf.crs}. "
        f"Esperado: EPSG:4674."
    )

print("CRS validado: SIRGAS 2000 / EPSG:4674")


# ============================================================
# 3. VALIDAR COLUNAS DA ORIGEM
# ============================================================

COLUNAS_ORIGEM = [
    "NUM_RODADA",
    "NOM_CAMPO",
    "AREA",
    "OPERADOR_C",
    "NUM_CONTRA",
    "DAT_ASSINA",
    "DAT_TERMIN",
    "NOM_BACIA",
    "COD_CAMPO",
    "SIG_CAMPO",
    "DAT_DESCOB",
    "DAT_INICIO",
    "ETAPA",
    "MED_LAMINA",
    "FLUIDO_PRI",
    "ID",
    "AMBIENTE",
    "geometry",
]

faltantes = [
    coluna
    for coluna in COLUNAS_ORIGEM
    if coluna not in gdf.columns
]

if faltantes:
    raise ValueError(
        f"Colunas obrigatórias ausentes no shapefile: {faltantes}"
    )

print("Colunas de origem validadas.")


# ============================================================
# 4. SELECIONAR E RENOMEAR COLUNAS
# ============================================================

df = gdf[COLUNAS_ORIGEM].copy()

df = df.rename(
    columns={
        "ID": "id_origem",
        "COD_CAMPO": "codigo_campo",
        "SIG_CAMPO": "sigla",
        "NOM_CAMPO": "nome",
        "NOM_BACIA": "bacia",
        "AREA": "area_km2",
        "NUM_CONTRA": "numero_contrato",
        "NUM_RODADA": "numero_rodada",
        "DAT_ASSINA": "data_assinatura",
        "DAT_TERMIN": "data_termino",
        "DAT_DESCOB": "data_descoberta",
        "DAT_INICIO": "data_inicio",
        "ETAPA": "etapa",
        "MED_LAMINA": "lamina_agua_m",
        "FLUIDO_PRI": "fluido_principal",
        "AMBIENTE": "ambiente",
    }
)


# ============================================================
# 5. OPERADORA
# ============================================================

# OPERADOR_C pertence ao domínio das empresas operadoras
# dos campos de petróleo.
#
# Não existe ainda uma relação entre OPERADOR_C e
# core.empresas.
#
# Portanto, neste momento:
#
#     OPERADOR_C -> apenas validação/log
#     operadora_id -> NULL
#
# O relacionamento será criado posteriormente.

operadoras_origem = (
    gdf["OPERADOR_C"]
    .dropna()
    .astype(str)
    .str.strip()
)

print(
    f"Operadoras distintas na origem: "
    f"{operadoras_origem.nunique()}"
)


# ============================================================
# 6. CONVERSÃO DAS DATAS
# ============================================================

COLUNAS_DATA = [
    "data_assinatura",
    "data_termino",
    "data_descoberta",
    "data_inicio",
]

for coluna in COLUNAS_DATA:

    df[coluna] = pd.to_datetime(
        df[coluna],
        errors="coerce",
        dayfirst=True
    ).dt.date


# ============================================================
# 7. CONVERSÃO DOS CAMPOS NUMÉRICOS
# ============================================================

df["id_origem"] = pd.to_numeric(
    df["id_origem"],
    errors="coerce"
)

df["codigo_campo"] = pd.to_numeric(
    df["codigo_campo"],
    errors="coerce"
)

df["area_km2"] = pd.to_numeric(
    df["area_km2"],
    errors="coerce"
)

df["lamina_agua_m"] = pd.to_numeric(
    df["lamina_agua_m"],
    errors="coerce"
)


# ============================================================
# 8. VALIDAR CAMPOS OBRIGATÓRIOS
# ============================================================

if df["codigo_campo"].isna().any():

    quantidade = df["codigo_campo"].isna().sum()

    raise ValueError(
        f"{quantidade} registros possuem "
        f"codigo_campo nulo."
    )


if df["nome"].isna().any():

    quantidade = df["nome"].isna().sum()

    raise ValueError(
        f"{quantidade} registros possuem "
        f"nome nulo."
    )


# ============================================================
# 9. TRATAMENTO DAS GEOMETRIAS
# ============================================================

print("\nValidando geometrias...")

# Corrigir geometrias inválidas quando possível

df["geometry"] = df["geometry"].make_valid()


def converter_para_multipolygon(geom):

    if geom is None:
        return None

    if geom.geom_type == "Polygon":

        from shapely.geometry import MultiPolygon

        return MultiPolygon([geom])

    if geom.geom_type == "MultiPolygon":
        return geom

    raise ValueError(
        f"Tipo de geometria inesperado: "
        f"{geom.geom_type}"
    )


df["geometry"] = df["geometry"].apply(
    converter_para_multipolygon
)


# Validar novamente

geometrias_nulas = df["geometry"].isna().sum()

geometrias_invalidas = (
    ~df["geometry"].is_valid
).sum()


if geometrias_nulas > 0:

    raise ValueError(
        f"{geometrias_nulas} geometrias nulas."
    )


if geometrias_invalidas > 0:

    raise ValueError(
        f"{geometrias_invalidas} geometrias inválidas."
    )


print("Geometrias validadas.")


# ============================================================
# 10. CRIAR DATAFRAME GEOPANDAS
# ============================================================

gdf_final = gpd.GeoDataFrame(
    df,
    geometry="geometry",
    crs=CRS_ESPERADO
)

gdf_final = gdf_final.rename_geometry("geom")


# ============================================================
# 11. SELECIONAR EXATAMENTE AS COLUNAS DO CORE.CAMPOS
# ============================================================

colunas_destino = [
    "id_origem",
    "codigo_campo",
    "sigla",
    "nome",
    "bacia",
    "operadora_id",
    "area_km2",
    "numero_contrato",
    "numero_rodada",
    "data_assinatura",
    "data_termino",
    "data_descoberta",
    "data_inicio",
    "etapa",
    "lamina_agua_m",
    "fluido_principal",
    "ambiente",
    "geom",
]


# operadora_id ainda não possui relacionamento

gdf_final["operadora_id"] = None


df_insert = gdf_final[colunas_destino].copy()


# ============================================================
# 12. VALIDAÇÃO FINAL ANTES DA CARGA
# ============================================================

print("\n" + "-" * 60)
print("VALIDAÇÃO FINAL")
print("-" * 60)

print(
    f"Campos para importar: {len(df_insert)}"
)

print(
    f"Códigos únicos: "
    f"{df_insert['codigo_campo'].nunique()}"
)

print(
    f"Nomes únicos: "
    f"{df_insert['nome'].nunique()}"
)

print(
    f"Geometrias: "
    f"{df_insert['geom'].geom_type.value_counts().to_dict()}"
)

print(
    f"Operadoras na origem: "
    f"{operadoras_origem.nunique()}"
)


# ============================================================
# 13. CARGA NO POSTGRESQL
# ============================================================

print("\nIniciando carga em core.campos...")


df_insert.to_postgis(
    name=TABELA,
    con=engine,
    schema=SCHEMA,
    if_exists="append",
    index=False,
    dtype={
        "geom": Geometry(
            geometry_type="MULTIPOLYGON",
            srid=4674
        )
    }
)


# ============================================================
# 14. VALIDAR RESULTADO NO BANCO
# ============================================================

with engine.connect() as conn:

    quantidade = conn.execute(
        text(
            """
            SELECT COUNT(*)
            FROM core.campos;
            """
        )
    ).scalar()

    quantidade_geometrias = conn.execute(
        text(
            """
            SELECT COUNT(*)
            FROM core.campos
            WHERE geom IS NOT NULL;
            """
        )
    ).scalar()


# ============================================================
# 15. RESULTADO
# ============================================================

print("\n" + "=" * 60)
print("CARGA CONCLUÍDA")
print("=" * 60)

print(
    f"Registros em core.campos: {quantidade}"
)

print(
    f"Registros com geometria: {quantidade_geometrias}"
)

print(
    f"Operadora ainda não relacionada: "
    f"operadora_id = NULL"
)

print("\nProcesso finalizado.")
# Out:
# ============================================================
# IMPORTAÇÃO DE CAMPOS DE PETRÓLEO
# ============================================================
#
# Lendo shapefile...
# C:\Users\roger\Anaconda3\envs\geo_video\lib\site-packages\geopandas\array.py:344: UserWarning: Cannot set the CRS, falling back to None. The CRS support requires the 'pyproj' package, but it is not installed or does not import correctly. The functions depending on CRS will raise an error or may produce unexpected results.
#   self.crs = crs
# C:\Users\roger\Anaconda3\envs\geo_video\lib\site-packages\geopandas\geodataframe.py:64: UserWarning: Cannot set the CRS, falling back to None. The CRS support requires the 'pyproj' package, but it is not installed or does not import correctly. The functions depending on CRS will raise an error or may produce unexpected results.
#   data.array.crs = crs
# C:\Users\roger\Anaconda3\envs\geo_video\lib\site-packages\geopandas\geodataframe.py:467: UserWarning: Cannot set the CRS, falling back to None. The CRS support requires the 'pyproj' package, but it is not installed or does not import correctly. The functions depending on CRS will raise an error or may produce unexpected results.
#   level.array.crs = crs
# Arquivo: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\shapefiles\CAMPOS_PRODUCAO_SIRGAS\CAMPOS_PRODUCAO_SIRGASPolygon.shp
# Registros encontrados: 427
# CRS encontrado: None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 56
#      51 # ============================================================
#      52 # 2. VALIDAR CRS
#      53 # ============================================================
#      55 if gdf.crs is None:
# ---> 56     raise ValueError(
#      57         "O shapefile não possui CRS definido."
#      58     )
#      60 if gdf.crs.to_epsg() != 4674:
#      61     raise ValueError(
#      62         f"CRS inesperado: {gdf.crs}. "
#      63         f"Esperado: EPSG:4674."
#      64     )
#
# ValueError: O shapefile não possui CRS definido.

# %%
import pyproj

print("pyproj:", pyproj.__version__)
print("PROJ:", pyproj.proj_version_str)
print("PROJ database:", pyproj.datadir.get_data_dir())

from pyproj import CRS

print(CRS.from_epsg(4674))
# Out:
# pyproj: 3.7.1
# PROJ: 9.6.2
# PROJ database: C:\Program Files\PostgreSQL\18\share\contrib\postgis-3.6\proj
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Cell In[6], line 9
#       5 print("PROJ database:", pyproj.datadir.get_data_dir())
#       7 from pyproj import CRS
# ----> 9 print(CRS.from_epsg(4674))
#
# File ~\Anaconda3\envs\geo_video\lib\site-packages\pyproj\crs\crs.py:394, in CRS.from_epsg(cls, code)
#     381 @classmethod
#     382 def from_epsg(cls, code: str | int) -> "CRS":
#     383     """Make a CRS from an EPSG code
#     384
#     385     Parameters
#    (...)
#     392     CRS
#     393     """
# --> 394     return cls.from_user_input(_prepare_from_epsg(code))
#
# File ~\Anaconda3\envs\geo_video\lib\site-packages\pyproj\crs\crs.py:503, in CRS.from_user_input(cls, value, **kwargs)
#     501 if isinstance(value, cls):
#     502     return value
# --> 503 return cls(value, **kwargs)
#
# File ~\Anaconda3\envs\geo_video\lib\site-packages\pyproj\crs\crs.py:350, in CRS.__init__(self, projparams, **kwargs)
#     348     self._local.crs = projparams
#     349 else:
# --> 350     self._local.crs = _CRS(self.srs)
#
# File ~\Anaconda3\envs\geo_video\lib\site-packages\pyproj\_crs.pyx:2364, in pyproj._crs._CRS.__init__()
#
# CRSError: Invalid projection: EPSG:4674: (Internal Proj Error: proj_create: no database context specified)

# %%
import pyproj

pyproj.datadir.set_data_dir(
    pyproj.datadir.get_data_dir()
)

print(pyproj.datadir.get_data_dir())
# Out:
# C:\Program Files\PostgreSQL\18\share\contrib\postgis-3.6\proj
# C:\Users\roger\Anaconda3\envs\geo_video\lib\site-packages\pyproj\datadir.py:38: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_data_dir()

# %%
from pyproj import CRS

print(CRS.from_epsg(4674))
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 from pyproj import CRS
# ----> 3 print(CRS.from_epsg(4674))
#
# File ~\Anaconda3\envs\geo_video\lib\site-packages\pyproj\crs\crs.py:394, in CRS.from_epsg(cls, code)
#     381 @classmethod
#     382 def from_epsg(cls, code: str | int) -> "CRS":
#     383     """Make a CRS from an EPSG code
#     384
#     385     Parameters
#    (...)
#     392     CRS
#     393     """
# --> 394     return cls.from_user_input(_prepare_from_epsg(code))
#
# File ~\Anaconda3\envs\geo_video\lib\site-packages\pyproj\crs\crs.py:503, in CRS.from_user_input(cls, value, **kwargs)
#     501 if isinstance(value, cls):
#     502     return value
# --> 503 return cls(value, **kwargs)
#
# File ~\Anaconda3\envs\geo_video\lib\site-packages\pyproj\crs\crs.py:350, in CRS.__init__(self, projparams, **kwargs)
#     348     self._local.crs = projparams
#     349 else:
# --> 350     self._local.crs = _CRS(self.srs)
#
# File ~\Anaconda3\envs\geo_video\lib\site-packages\pyproj\_crs.pyx:2364, in pyproj._crs._CRS.__init__()
#
# CRSError: Invalid projection: EPSG:4674: (Internal Proj Error: proj_create: no database context specified)

# %%
import pandas as pd

ARQUIVO = BASE / "dados" / "SURVEY_BRAM.xlsx"

df = pd.read_excel(
    ARQUIVO,
    sheet_name="BRAM ATLAS"
)

print("DIMENSÕES:", df.shape)

print("\nCOLUNAS:")
print(df.columns.tolist())

print("\nPRIMEIRAS LINHAS:")
display(df.head(10))

print("\nTIPOS:")
print(df.dtypes)
# Out:
# DIMENSÕES: (19, 19)
#
# COLUNAS:
# ['data_consulta', 'hora_consulta', 'partida', 'data_p', 'hora_p', 'lat_p', 'lon_p', 'chegada', 'data_c', 'hora_c', 'lat_c', 'lon_c', 'lat_a', 'lon_a', 'velocidade', 'rumo', 'data_reportada', 'hora_reportada', 'status']
#
# PRIMEIRAS LINHAS:
#         data_consulta hora_consulta partida data_p hora_p lat_p lon_p chegada  \
# 0 2026-07-16 20:40:00      20:40:00      na     na     na    na    na      na
# 1 2026-07-17 15:15:00      15:15:00     NaN    NaN    NaN   NaN   NaN     NaN
# 2 2026-07-21 05:33:00      05:33:00     NaN    NaN    NaN   NaN   NaN     NaN
# 3 2026-07-21 20:15:00            na     NaN    NaN    NaN   NaN   NaN     NaN
# 4 2026-07-22 05:30:00            na     NaN    NaN    NaN   NaN   NaN     NaN
# 5 2026-07-22 20:37:00            na     NaN    NaN    NaN   NaN   NaN     NaN
# 6 2026-07-23 08:28:00            na     NaN    NaN    NaN   NaN   NaN     NaN
# 7 2026-07-23 21:36:00           NaN     NaN    NaN    NaN   NaN   NaN     NaN
# 8 2026-07-24 06:57:00           NaN     NaN    NaN    NaN   NaN   NaN     NaN
# 9 2026-07-24 21:17:00           NaN     NaN    NaN    NaN   NaN   NaN     NaN
#
#   data_c hora_c lat_c lon_c      lat_a      lon_a  velocidade   rumo  \
# 0     na     na    na    na -22.880000 -43.130000        10.0  166.0
# 1    NaN    NaN   NaN   NaN -23.810000 -43.770000         6.1  164.0
# 2    NaN    NaN   NaN   NaN -24.703400 -42.409164         0.0    0.0
# 3    NaN    NaN   NaN   NaN -24.771299 -42.018955         NaN    NaN
# 4    NaN    NaN   NaN   NaN -24.700127 -42.407646         NaN    NaN
# 5    NaN    NaN   NaN   NaN -24.703123 -42.408306         NaN    NaN
# 6    NaN    NaN   NaN   NaN -24.703850 -42.405991         NaN    NaN
# 7    NaN    NaN   NaN   NaN -24.703659 -42.405407         NaN    NaN
# 8    NaN    NaN   NaN   NaN -24.703659 -42.405407         NaN    NaN
# 9    NaN    NaN   NaN   NaN -24.703659 -42.405407         NaN    NaN
#
#        data_reportada hora_reportada                      status
# 0 2026-07-16 20:40:00       20:40:00       Underway using Engine
# 1 2026-07-17 06:17:00       06:17:00       Underway using Engine
# 2 2026-07-21 05:33:00       05:33:00                      ACTIVE
# 3 2026-07-21 19:27:00             na  Restricted Manoeuvrability
# 4 2026-07-22 05:17:00             na  Restricted Manoeuvrability
# 5 2026-07-22 20:37:00             na  Restricted Manoeuvrability
# 6 2026-07-23 08:28:00             na  Restricted Manoeuvrability
# 7 2026-07-23 11:32:00            NaN  Restricted Manoeuvrability
# 8 2026-07-23 11:32:00            NaN  Restricted Manoeuvrability
# 9 2026-07-23 11:32:00            NaN  Restricted Manoeuvrability
# TIPOS:
# data_consulta     datetime64[ns]
# hora_consulta             object
# partida                   object
# data_p                    object
# hora_p                    object
# lat_p                     object
# lon_p                     object
# chegada                   object
# data_c                    object
# hora_c                    object
# lat_c                     object
# lon_c                     object
# lat_a                    float64
# lon_a                    float64
# velocidade               float64
# rumo                     float64
# data_reportada    datetime64[ns]
# hora_reportada            object
# status                    object
# dtype: object
