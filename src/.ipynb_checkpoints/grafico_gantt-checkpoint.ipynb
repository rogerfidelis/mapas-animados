# %%
import pandas as pd
import plotly.express as px
from gerar_mapa import BASE
import numpy as np
import plotly.io as pio


# ============================================================
# CONFIGURAÇÕES
# ============================================================

EMPRESAS = ["cbo", "bram", "starnav"]

# Cor padrão do tema OFI
COR_FUNDO = "#0B1F3A"
COR_TEXTO = "#FFFFFF"


# ============================================================
# PROCESSAMENTO DAS EMPRESAS
# ============================================================

for EMPRESA in EMPRESAS:
    
    ARQUIVO =  BASE  / "dados"  / f"SURVEY_{EMPRESA}_D2.xlsx" 


    # ========================================================
    # DIRETÓRIO DE SAÍDA
    # ========================================================
    PASTA_SAIDA =  BASE / "graficos" / "gantt_atendimento" / EMPRESA
    
    PASTA_SAIDA.mkdir(
        parents=True,
        exist_ok=True
    )


    # ========================================================
    # LEITURA DOS DADOS
    # ========================================================

    abas = pd.read_excel(ARQUIVO, sheet_name=None )


    # ========================================================
    # PROCESSAMENTO DAS ABAS
    # ========================================================

    for nome_aba, df in abas.items():

        # ----------------------------------------------------
        # Ignora aba de posições
        # ----------------------------------------------------

        if nome_aba.lower() == "posicoes":
            continue


        print(f"\n{'=' * 70}")
        print(f"Processando Gantt: {nome_aba}")
        print(f"{'=' * 70}")


        # ====================================================
        # PREPARAÇÃO DOS DADOS
        # ====================================================

        colunas_necessarias = [
            "evidencia_proximidade",
            "data_reportada",
            "unidade_proxima"
        ]


        colunas_faltantes = [
            coluna
            for coluna in colunas_necessarias
            if coluna not in df.columns
        ]


        if colunas_faltantes:

            print(
                f"Colunas ausentes na aba {nome_aba}: "
                f"{colunas_faltantes}"
            )

            continue


        # ----------------------------------------------------
        # Converte evidência para número
        # ----------------------------------------------------

        df["evidencia_proximidade"] = pd.to_numeric(
            df["evidencia_proximidade"],
            errors="coerce"
        )


        # ----------------------------------------------------
        # Converte data
        # ----------------------------------------------------

        df["data_reportada"] = pd.to_datetime(
            df["data_reportada"],
            dayfirst=True,
            errors="coerce"
        )


        # ----------------------------------------------------
        # Remove linhas sem data
        # ----------------------------------------------------

        df_base = (
            df
            .dropna(subset=["data_reportada"])
            .sort_values("data_reportada")
            .reset_index(drop=True)
        )


        # ----------------------------------------------------
        # Evidência suficiente
        # ----------------------------------------------------

        df_base["atendimento"] = (
            df_base["evidencia_proximidade"] >= 0.5
        )


        # ====================================================
        # CONSTRUÇÃO DOS EVENTOS
        # ====================================================

        registros_gantt = []

        evento_atual = None


        for i in range(len(df_base)):

            linha = df_base.iloc[i]

            data = linha["data_reportada"]

            evidencia = linha["evidencia_proximidade"]

            unidade = linha["unidade_proxima"]


            # =================================================
            # EVIDÊNCIA INSUFICIENTE
            # =================================================

            if pd.isna(evidencia) or evidencia < 0.5:

                if evento_atual is not None:

                    evento_atual["Fim"] = data

                    if (
                        evento_atual["Fim"]
                        > evento_atual["Inicio"]
                    ):

                        registros_gantt.append(
                            evento_atual.copy()
                        )

                    evento_atual = None

                continue


            # =================================================
            # UNIDADE INEXISTENTE
            # =================================================

            if pd.isna(unidade):

                if evento_atual is not None:

                    evento_atual["Fim"] = data

                    if (
                        evento_atual["Fim"]
                        > evento_atual["Inicio"]
                    ):

                        registros_gantt.append(
                            evento_atual.copy()
                        )

                    evento_atual = None

                continue


            # =================================================
            # PRIMEIRO EVENTO
            # =================================================

            if evento_atual is None:

                evento_atual = {

                    "Inicio": data,

                    "Fim": data,

                    "Origem": unidade,

                    "Destino": unidade,

                    "Tipo": "Parado",

                    "Atividade": unidade

                }

                continue


            # =================================================
            # UNIDADE ATUAL
            # =================================================

            origem_atual = evento_atual["Destino"]


            # =================================================
            # MESMA UNIDADE
            # =================================================

            if unidade == origem_atual:

                evento_atual["Fim"] = data

                continue


            # =================================================
            # MUDANÇA DE UNIDADE
            # =================================================

            evento_atual["Fim"] = data


            if (
                evento_atual["Fim"]
                > evento_atual["Inicio"]
            ):

                registros_gantt.append(
                    evento_atual.copy()
                )


            # -------------------------------------------------
            # Novo evento de trânsito
            # -------------------------------------------------

            evento_atual = {

                "Inicio": data,

                "Fim": data,

                "Origem": origem_atual,

                "Destino": unidade,

                "Tipo": "Trânsito",

                "Atividade": (
                    f"{origem_atual} → {unidade}"
                )

            }


        # ====================================================
        # FECHA EVENTO FINAL
        # ====================================================

        if evento_atual is not None:

            ultima_data = (
                df_base.iloc[-1]["data_reportada"]
            )

            evento_atual["Fim"] = ultima_data


            if (
                evento_atual["Fim"]
                > evento_atual["Inicio"]
            ):

                registros_gantt.append(
                    evento_atual.copy()
                )


        # ====================================================
        # DATAFRAME DO GANTT
        # ====================================================

        df_gantt = pd.DataFrame(
            registros_gantt
        )


        if df_gantt.empty:

            print(
                f"Nenhum evento válido: {nome_aba}"
            )

            continue


        # ====================================================
        # REMOVE INTERVALOS INVÁLIDOS
        # ====================================================

        df_gantt = df_gantt[
            df_gantt["Fim"]
            > df_gantt["Inicio"]
        ].reset_index(drop=True)


        if df_gantt.empty:

            print(
                f"Nenhum intervalo válido: {nome_aba}"
            )

            continue


        # ====================================================
        # DURAÇÃO
        # ====================================================

        df_gantt["Duracao"] = (
            df_gantt["Fim"]
            - df_gantt["Inicio"]
        )


        # ====================================================
        # ID DO EVENTO
        # ====================================================

        df_gantt["id_evento"] = np.arange(
            len(df_gantt)
        )


        # ====================================================
        # EIXO Y
        # ====================================================

        df_gantt["Atividade_Y"] = (

            df_gantt["id_evento"]
            .astype(str)

            + " - "

            + df_gantt["Atividade"]
        )


        ordem_eventos = (
            df_gantt["Atividade_Y"]
            .tolist()
        )


        # ====================================================
        # CORES DAS ATIVIDADES
        # ====================================================

        cores_tipo = {

            "Trânsito": "#1CA3EC",

            "Parado": "#D4AF37"

        }


        # ====================================================
        # GANTT
        # ====================================================

        fig = px.timeline(

            df_gantt,

            x_start="Inicio",

            x_end="Fim",

            y="Atividade_Y",

            color="Tipo",

            color_discrete_map=cores_tipo,

            hover_data={

                "Origem": True,

                "Destino": True,

                "Duracao": True,

                "Tipo": True,

                "Inicio": True,

                "Fim": True,

                "Atividade_Y": False

            },

            category_orders={

                "Atividade_Y": ordem_eventos

            }

        )


        # ====================================================
        # EIXO X
        # ====================================================

        fig.update_xaxes(

            title_text="Data / Hora",

            title_font=dict(
                size=18,
                color=COR_TEXTO
            ),

            tickfont=dict(
                size=14,
                color=COR_TEXTO
            ),

            tickformat="%d/%m %H:%M",

            dtick=6 * 60 * 60 * 1000,

            automargin=True,

            color=COR_TEXTO,

            gridcolor="rgba(255,255,255,0.15)",

            zerolinecolor="rgba(255,255,255,0.20)"

        )


        # ====================================================
        # EIXO Y
        # ====================================================

        fig.update_yaxes(

            title_text="Atividade",

            title_font=dict(
                size=18,
                color=COR_TEXTO
            ),

            tickfont=dict(
                size=14,
                color=COR_TEXTO
            ),

            automargin=True,

            color=COR_TEXTO,

            gridcolor="rgba(255,255,255,0.08)",

            zerolinecolor="rgba(255,255,255,0.15)"

        )


        # ====================================================
        # ALTURA DO GANTT
        # ====================================================

        altura_gantt = max(
            500,
            len(df_gantt) * 35
        )


        # ====================================================
        # LAYOUT
        # ====================================================

        fig.update_layout(

            autosize=True,

            height=altura_gantt,

            # -----------------------------------------------
            # FUNDO
            # -----------------------------------------------

            paper_bgcolor=COR_FUNDO,

            plot_bgcolor=COR_FUNDO,

            # -----------------------------------------------
            # MARGENS
            # -----------------------------------------------

            margin=dict(

                l=220,

                r=30,

                t=100,

                b=60

            ),

            # -----------------------------------------------
            # FONTE PADRÃO
            # -----------------------------------------------

            font=dict(

                size=16,

                family="Arial",

                color=COR_TEXTO

            ),

            # -----------------------------------------------
            # TÍTULO
            # -----------------------------------------------

            title=dict(

                text=f"""
                <b>Atendimento Offshore</b><br>
                <span style='font-size:16px'>{nome_aba}</span>
                """,

                font=dict(

                    size=20,

                    color=COR_TEXTO

                ),

                x=0.5,

                xanchor="center"

            ),

            # -----------------------------------------------
            # LEGENDA
            # -----------------------------------------------

            legend=dict(

                title="Tipo de atendimento",

                title_font=dict(

                    size=14,

                    color=COR_TEXTO

                ),

                font=dict(

                    size=13,

                    color=COR_TEXTO

                ),

                bgcolor="rgba(0,0,0,0)"

            )

        )


        # ====================================================
        # BARRAS
        # ====================================================

        fig.update_traces(

            marker_line_color=COR_FUNDO,

            marker_line_width=1

        )


        # ====================================================
        # NOME DO ARQUIVO
        # ====================================================

        def normalizar_nome(nome_aba):
            return (
                str(nome_aba)
                .strip()
                .lower()
                .replace("/", "_")
                .replace("\\", "_")
                .replace(" ", "_")
            )

    
    
    # nome_arquivo = ( str(nome_aba)
          #  .strip()
          #  .lower()
          #  .replace("/", "_")
          #  .replace("\\", "_")
          #  .replace(" ", "_")
      #  )
        nome_arquivo = normalizar_nome(nome_aba)

        arquivo_saida = PASTA_SAIDA / f"{nome_arquivo}.html" 
                         
                         
        # ====================================================
        # SALVAMENTO
        # ====================================================
        
        print("\n" + "=" * 70)
        print("VERIFICAÇÃO DO ARQUIVO")
        print("=" * 70)

        print("Empresa:", EMPRESA)
        print("Aba:", repr(nome_aba))
        print("Nome arquivo:", nome_arquivo)
        print("Caminho:", arquivo_saida)
        print("Existe:", arquivo_saida.exists())
        print("Arquivo:", arquivo_saida.name)

        fig.write_html(

            arquivo_saida,

            full_html=True,

            include_plotlyjs=True,

            config={

                "responsive": True,

                "displayModeBar": True,

                "scrollZoom": False

            }

        )


        print(f"Gantt salvo em:\n{arquivo_saida}" )
# Out:
# ======================================================================
# Processando Gantt: CBO ALESSANDRA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO ALESSANDRA'
# Nome arquivo: cbo_alessandra
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_alessandra.html
# Existe: True
# Arquivo: cbo_alessandra.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_alessandra.html
#
# ======================================================================
# Processando Gantt: CBO ALIANCA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO ALIANCA'
# Nome arquivo: cbo_alianca
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_alianca.html
# Existe: True
# Arquivo: cbo_alianca.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_alianca.html
#
# ======================================================================
# Processando Gantt: CBO ANITA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO ANITA'
# Nome arquivo: cbo_anita
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_anita.html
# Existe: True
# Arquivo: cbo_anita.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_anita.html
#
# ======================================================================
# Processando Gantt: CBO ARPOADOR
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO ARPOADOR'
# Nome arquivo: cbo_arpoador
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_arpoador.html
# Existe: True
# Arquivo: cbo_arpoador.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_arpoador.html
#
# ======================================================================
# Processando Gantt: CBO CAMPOS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO CAMPOS'
# Nome arquivo: cbo_campos
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_campos.html
# Existe: True
# Arquivo: cbo_campos.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_campos.html
#
# ======================================================================
# Processando Gantt: CBO CAROLINA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO CAROLINA'
# Nome arquivo: cbo_carolina
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_carolina.html
# Existe: True
# Arquivo: cbo_carolina.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_carolina.html
#
# ======================================================================
# Processando Gantt: CBO COPACABANA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO COPACABANA'
# Nome arquivo: cbo_copacabana
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_copacabana.html
# Existe: True
# Arquivo: cbo_copacabana.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_copacabana.html
#
# ======================================================================
# Processando Gantt: CBO ENERGY
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO ENERGY'
# Nome arquivo: cbo_energy
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_energy.html
# Existe: False
# Arquivo: cbo_energy.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_energy.html
#
# ======================================================================
# Processando Gantt: CBO FLAMENGO
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO FLAMENGO'
# Nome arquivo: cbo_flamengo
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_flamengo.html
# Existe: True
# Arquivo: cbo_flamengo.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_flamengo.html
#
# ======================================================================
# Processando Gantt: CBO IPANEMA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO IPANEMA'
# Nome arquivo: cbo_ipanema
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_ipanema.html
# Existe: True
# Arquivo: cbo_ipanema.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_ipanema.html
#
# ======================================================================
# Processando Gantt: CBO ISABELLA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO ISABELLA'
# Nome arquivo: cbo_isabella
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_isabella.html
# Existe: True
# Arquivo: cbo_isabella.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_isabella.html
#
# ======================================================================
# Processando Gantt: CBO ITAJAI
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO ITAJAI'
# Nome arquivo: cbo_itajai
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_itajai.html
# Existe: True
# Arquivo: cbo_itajai.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_itajai.html
#
# ======================================================================
# Processando Gantt: CBO MANOELLA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO MANOELLA'
# Nome arquivo: cbo_manoella
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_manoella.html
# Existe: True
# Arquivo: cbo_manoella.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_manoella.html
#
# ======================================================================
# Processando Gantt: CBO OCEANA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO OCEANA'
# Nome arquivo: cbo_oceana
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_oceana.html
# Existe: True
# Arquivo: cbo_oceana.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_oceana.html
#
# ======================================================================
# Processando Gantt: CBO RENATA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO RENATA'
# Nome arquivo: cbo_renata
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_renata.html
# Existe: True
# Arquivo: cbo_renata.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_renata.html
#
# ======================================================================
# Processando Gantt: CBO RIO
# ======================================================================
# Nenhum evento válido: CBO RIO
#
# ======================================================================
# Processando Gantt: CBO SUPPORTER
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO SUPPORTER'
# Nome arquivo: cbo_supporter
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_supporter.html
# Existe: True
# Arquivo: cbo_supporter.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_supporter.html
#
# ======================================================================
# Processando Gantt: CBO VITORIA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO VITORIA'
# Nome arquivo: cbo_vitoria
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_vitoria.html
# Existe: True
# Arquivo: cbo_vitoria.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_vitoria.html
#
# ======================================================================
# Processando Gantt: CBO WAVE
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO WAVE'
# Nome arquivo: cbo_wave
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_wave.html
# Existe: True
# Arquivo: cbo_wave.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_wave.html
#
# ======================================================================
# Processando Gantt: CBO WISER
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'CBO WISER'
# Nome arquivo: cbo_wiser
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_wiser.html
# Existe: True
# Arquivo: cbo_wiser.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\cbo_wiser.html
#
# ======================================================================
# Processando Gantt: DELTA CARDINAL
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'DELTA CARDINAL'
# Nome arquivo: delta_cardinal
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\delta_cardinal.html
# Existe: True
# Arquivo: delta_cardinal.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\delta_cardinal.html
#
# ======================================================================
# Processando Gantt: DELTA COMMANDER
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: cbo
# Aba: 'DELTA COMMANDER'
# Nome arquivo: delta_commander
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\delta_commander.html
# Existe: True
# Arquivo: delta_commander.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\cbo\delta_commander.html
#
# ======================================================================
# Processando Gantt: BRAM ATLAS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM ATLAS'
# Nome arquivo: bram_atlas
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_atlas.html
# Existe: True
# Arquivo: bram_atlas.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_atlas.html
#
# ======================================================================
# Processando Gantt: BRAM BAHIA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM BAHIA'
# Nome arquivo: bram_bahia
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_bahia.html
# Existe: True
# Arquivo: bram_bahia.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_bahia.html
#
# ======================================================================
# Processando Gantt: BRAM BELEM
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM BELEM'
# Nome arquivo: bram_belem
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_belem.html
# Existe: True
# Arquivo: bram_belem.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_belem.html
#
# ======================================================================
# Processando Gantt: BRAM BRASIL
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM BRASIL'
# Nome arquivo: bram_brasil
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_brasil.html
# Existe: True
# Arquivo: bram_brasil.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_brasil.html
#
# ======================================================================
# Processando Gantt: BRAM BRASILIA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM BRASILIA'
# Nome arquivo: bram_brasilia
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_brasilia.html
# Existe: True
# Arquivo: bram_brasilia.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_brasilia.html
#
# ======================================================================
# Processando Gantt: BRAM BRAVO
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM BRAVO'
# Nome arquivo: bram_bravo
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_bravo.html
# Existe: True
# Arquivo: bram_bravo.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_bravo.html
#
# ======================================================================
# Processando Gantt: BRAM BREEZE
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM BREEZE'
# Nome arquivo: bram_breeze
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_breeze.html
# Existe: True
# Arquivo: bram_breeze.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_breeze.html
#
# ======================================================================
# Processando Gantt: BRAM BUCK
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM BUCK'
# Nome arquivo: bram_buck
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_buck.html
# Existe: True
# Arquivo: bram_buck.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_buck.html
#
# ======================================================================
# Processando Gantt: BRAM BUZIOS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM BUZIOS'
# Nome arquivo: bram_buzios
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_buzios.html
# Existe: True
# Arquivo: bram_buzios.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_buzios.html
#
# ======================================================================
# Processando Gantt: BRAM HERO
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM HERO'
# Nome arquivo: bram_hero
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_hero.html
# Existe: True
# Arquivo: bram_hero.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_hero.html
#
# ======================================================================
# Processando Gantt: BRAM POWER
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM POWER'
# Nome arquivo: bram_power
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_power.html
# Existe: True
# Arquivo: bram_power.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_power.html
#
# ======================================================================
# Processando Gantt: BRAM RIO
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM RIO'
# Nome arquivo: bram_rio
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_rio.html
# Existe: True
# Arquivo: bram_rio.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_rio.html
#
# ======================================================================
# Processando Gantt: BRAM SPIRIT
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM SPIRIT'
# Nome arquivo: bram_spirit
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_spirit.html
# Existe: True
# Arquivo: bram_spirit.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_spirit.html
#
# ======================================================================
# Processando Gantt: BRAM TITAN
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: bram
# Aba: 'BRAM TITAN'
# Nome arquivo: bram_titan
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_titan.html
# Existe: True
# Arquivo: bram_titan.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\bram\bram_titan.html
# ======================================================================
# Processando Gantt: STARNAV ANDROMEDA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV ANDROMEDA'
# Nome arquivo: starnav_andromeda
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_andromeda.html
# Existe: True
# Arquivo: starnav_andromeda.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_andromeda.html
#
# ======================================================================
# Processando Gantt: STARNAV AQUARIUS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV AQUARIUS'
# Nome arquivo: starnav_aquarius
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_aquarius.html
# Existe: True
# Arquivo: starnav_aquarius.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_aquarius.html
#
# ======================================================================
# Processando Gantt: STARNAV AQUILA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV AQUILA'
# Nome arquivo: starnav_aquila
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_aquila.html
# Existe: True
# Arquivo: starnav_aquila.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_aquila.html
#
# ======================================================================
# Processando Gantt: STARNAV CENTAURUS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV CENTAURUS'
# Nome arquivo: starnav_centaurus
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_centaurus.html
# Existe: True
# Arquivo: starnav_centaurus.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_centaurus.html
#
# ======================================================================
# Processando Gantt: STARNAV CEPHEUS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV CEPHEUS'
# Nome arquivo: starnav_cepheus
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_cepheus.html
# Existe: True
# Arquivo: starnav_cepheus.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_cepheus.html
#
# ======================================================================
# Processando Gantt: STARNAV CIRCINUS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV CIRCINUS'
# Nome arquivo: starnav_circinus
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_circinus.html
# Existe: True
# Arquivo: starnav_circinus.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_circinus.html
#
# ======================================================================
# Processando Gantt: STARNAV CYGNUS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV CYGNUS'
# Nome arquivo: starnav_cygnus
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_cygnus.html
# Existe: True
# Arquivo: starnav_cygnus.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_cygnus.html
#
# ======================================================================
# Processando Gantt: STARNAV DELPHINUS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV DELPHINUS'
# Nome arquivo: starnav_delphinus
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_delphinus.html
# Existe: True
# Arquivo: starnav_delphinus.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_delphinus.html
#
# ======================================================================
# Processando Gantt: STARNAV DRACO
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV DRACO'
# Nome arquivo: starnav_draco
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_draco.html
# Existe: True
# Arquivo: starnav_draco.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_draco.html
#
# ======================================================================
# Processando Gantt: STARNAV HYDRA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV HYDRA'
# Nome arquivo: starnav_hydra
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_hydra.html
# Existe: True
# Arquivo: starnav_hydra.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_hydra.html
#
# ======================================================================
# Processando Gantt: STARNAV LIBRA
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV LIBRA'
# Nome arquivo: starnav_libra
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_libra.html
# Existe: True
# Arquivo: starnav_libra.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_libra.html
#
# ======================================================================
# Processando Gantt: STARNAV PERSEUS
# ======================================================================
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV PERSEUS'
# Nome arquivo: starnav_perseus
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_perseus.html
# Existe: True
# Arquivo: starnav_perseus.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_perseus.html
#
# ======================================================================
# Processando Gantt: STARNAV PHOENIX
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV PHOENIX'
# Nome arquivo: starnav_phoenix
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_phoenix.html
# Existe: True
# Arquivo: starnav_phoenix.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_phoenix.html
#
# ======================================================================
# Processando Gantt: STARNAV REGULUS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV REGULUS'
# Nome arquivo: starnav_regulus
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_regulus.html
# Existe: True
# Arquivo: starnav_regulus.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_regulus.html
#
# ======================================================================
# Processando Gantt: STARNAV TAURUS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV TAURUS'
# Nome arquivo: starnav_taurus
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_taurus.html
# Existe: True
# Arquivo: starnav_taurus.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_taurus.html
#
# ======================================================================
# Processando Gantt: STARNAV URSUS
# ======================================================================
# Nenhum evento válido: STARNAV URSUS
#
# ======================================================================
# Processando Gantt: STARNAV VOLANS
# ======================================================================
#
# ======================================================================
# VERIFICAÇÃO DO ARQUIVO
# ======================================================================
# Empresa: starnav
# Aba: 'STARNAV VOLANS'
# Nome arquivo: starnav_volans
# Caminho: C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_volans.html
# Existe: True
# Arquivo: starnav_volans.html
# Gantt salvo em:
# C:\Users\roger\OneDrive - cefet-rj.br\Empresas e entrevistas\projeto logistica offshore\ofi\graficos\gantt_atendimento\starnav\starnav_volans.html
