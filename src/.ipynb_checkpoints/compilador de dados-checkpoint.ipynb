# %%
#wb.sheetnames

# %%
from openpyxl import load_workbook
import pandas as pd
from gerar_mapa import BASE



EMPRESAS = ["cbo", "bram", "starnav"]

for EMPRESA in EMPRESAS:

    # Arquivo origem (A)
    ARQUIVO_ORIGEM = BASE / "dados" / "SURVEY_VESSELS"/"SURVEY_VESSELS_20260731_tarde.xlsx"
    origem = pd.read_excel(ARQUIVO_ORIGEM, sheet_name= EMPRESA)

    # =========================
    # CABEÇALHOS DA PLANILHA A
    # =========================

    cabecalhos_A = {}

    for i, coluna in enumerate(origem.columns):
        cabecalhos_A[str(coluna).strip()] = i

    print(cabecalhos_A)

    # Arquivo destino (B)
    ARQUIVO_DESTINO = BASE / "dados" /f"SURVEY_{EMPRESA.upper()}.xlsx"

    wb = load_workbook(ARQUIVO_DESTINO)

    # =========================
    # TESTE
    # =========================
    for _, linha in origem.iterrows():

        # Nome da aba de destino
        aba = str(linha.iloc[0]).strip().upper()

        print(f"Procurando aba: {aba}")

        # Verifica se a aba existe
        if aba not in wb.sheetnames:
            print(f"Aba '{aba}' não encontrada!")
            continue

        # Abre a aba
        ws = wb[aba]

        print(f"Aba encontrada: {ws.title}")

        # Apenas para testar a primeira embarcação

        # =========================
        # CABEÇALHOS DA ABA DESTINO
        # =========================

        cabecalhos_B = {}

        for coluna in range(1, ws.max_column + 1):

            nome_coluna = ws.cell(row=1, column=coluna).value

            if nome_coluna is not None:
                cabecalhos_B[str(nome_coluna).strip()] = coluna


        mapeamento= {
                         "data": "data_consulta",
                         "hora": "hora_consulta",
                         "lat": "lat_a",
                         "lon": "lon_a",
                         "data reportada": "data_reportada",
                         "hora reportada": "hora_reportada",
                         "status": "status"
                     }

        ws = wb[aba]

        linha_destino = ws.max_row + 1

        #print(f"Próxima linha livre: {linha_destino}")

        for coluna_origem, coluna_destino in mapeamento.items():

            # Verifica se a coluna existe nas duas planilhas
            if coluna_origem not in cabecalhos_A:
                print(f"Coluna '{coluna_origem}' não existe na planilha A.")
                continue

            if coluna_destino not in cabecalhos_B:
                print(f"Coluna '{coluna_destino}' não existe na aba {aba}.")
                continue

            # Copia o valor
            valor = linha[coluna_origem]

            # Escreve na planilha destino
            ws.cell(
                row=linha_destino,
                column=cabecalhos_B[coluna_destino]
            ).value = valor

    wb.save(ARQUIVO_DESTINO)
# Out:
# {'cbo': 0, 'data': 1, 'hora': 2, 'lat': 3, 'lon': 4, 'data reportada': 5, 'hora reportada': 6, 'status': 7}
# Procurando aba: CBO ALESSANDRA
# Aba encontrada: CBO ALESSANDRA
# Procurando aba: CBO ALIANCA
# Aba encontrada: CBO ALIANCA
# Procurando aba: CBO ANITA
# Aba encontrada: CBO ANITA
# Procurando aba: CBO ARPOADOR
# Aba encontrada: CBO ARPOADOR
# Procurando aba: CBO CAMPOS
# Aba encontrada: CBO CAMPOS
# Procurando aba: CBO CAROLINA
# Aba encontrada: CBO CAROLINA
# Procurando aba: CBO COPACABANA
# Aba encontrada: CBO COPACABANA
# Procurando aba: CBO ENERGY
# Aba encontrada: CBO ENERGY
# Procurando aba: CBO FLAMENGO
# Aba encontrada: CBO FLAMENGO
# Procurando aba: CBO IPANEMA
# Aba encontrada: CBO IPANEMA
# Procurando aba: CBO ISABELLA
# Aba encontrada: CBO ISABELLA
# Procurando aba: CBO ITAJAI
# Aba encontrada: CBO ITAJAI
# Procurando aba: CBO MANOELLA
# Aba encontrada: CBO MANOELLA
# Procurando aba: CBO OCEANA
# Aba encontrada: CBO OCEANA
# Procurando aba: CBO RENATA
# Aba encontrada: CBO RENATA
# Procurando aba: CBO RIO
# Aba encontrada: CBO RIO
# Procurando aba: CBO SUPPORTER
# Aba encontrada: CBO SUPPORTER
# Procurando aba: CBO VITORIA
# Aba encontrada: CBO VITORIA
# Procurando aba: CBO WAVE
# Aba encontrada: CBO WAVE
# Procurando aba: CBO WISER
# Aba encontrada: CBO WISER
# Procurando aba: DELTA CARDINAL
# Aba encontrada: DELTA CARDINAL
# Procurando aba: DELTA COMMANDER
# Aba encontrada: DELTA COMMANDER
# {'bram': 0, 'data': 1, 'hora': 2, 'lat': 3, 'lon': 4, 'data reportada': 5, 'hora reportada': 6, 'status': 7}
# Procurando aba: BRAM ATLAS
# Aba encontrada: BRAM ATLAS
# Procurando aba: BRAM BAHIA
# Aba encontrada: BRAM BAHIA
# Procurando aba: BRAM BELEM
# Aba encontrada: BRAM BELEM
# Procurando aba: BRAM BRASIL
# Aba encontrada: BRAM BRASIL
# Procurando aba: BRAM BRASILIA
# Aba encontrada: BRAM BRASILIA
# Procurando aba: BRAM BRAVO
# Aba encontrada: BRAM BRAVO
# Procurando aba: BRAM BREEZE
# Aba encontrada: BRAM BREEZE
# Procurando aba: BRAM BUCK
# Aba encontrada: BRAM BUCK
# Procurando aba: BRAM BUZIOS
# Aba encontrada: BRAM BUZIOS
# Procurando aba: BRAM HERO
# Aba encontrada: BRAM HERO
# Procurando aba: BRAM POWER
# Aba encontrada: BRAM POWER
# Procurando aba: BRAM RIO
# Aba encontrada: BRAM RIO
# Procurando aba: BRAM SPIRIT
# Aba encontrada: BRAM SPIRIT
# Procurando aba: BRAM TITAN
# Aba encontrada: BRAM TITAN
# {'starnav': 0, 'data': 1, 'hora': 2, 'lat': 3, 'lon': 4, 'data reportada': 5, 'hora reportada': 6, 'status': 7}
# Procurando aba: STARNAV ANDROMEDA
# Aba encontrada: STARNAV ANDROMEDA
# Procurando aba: STARNAV AQUARIUS
# Aba encontrada: STARNAV AQUARIUS
# Procurando aba: STARNAV AQUILA
# Aba encontrada: STARNAV AQUILA
# Procurando aba: STARNAV CENTAURUS
# Aba encontrada: STARNAV CENTAURUS
# Procurando aba: STARNAV CEPHEUS
# Aba encontrada: STARNAV CEPHEUS
# Procurando aba: STARNAV CIRCINUS
# Aba encontrada: STARNAV CIRCINUS
# Procurando aba: STARNAV CYGNUS
# Aba encontrada: STARNAV CYGNUS
# Procurando aba: STARNAV DELPHINUS
# Aba encontrada: STARNAV DELPHINUS
# Procurando aba: STARNAV DRACO
# Aba encontrada: STARNAV DRACO
# Procurando aba: STARNAV HYDRA
# Aba encontrada: STARNAV HYDRA
# Procurando aba: STARNAV LIBRA
# Aba encontrada: STARNAV LIBRA
# Procurando aba: STARNAV PERSEUS
# Aba encontrada: STARNAV PERSEUS
# Procurando aba: STARNAV PHOENIX
# Aba encontrada: STARNAV PHOENIX
# Procurando aba: STARNAV REGULUS
# Aba encontrada: STARNAV REGULUS
# Procurando aba: STARNAV TAURUS
# Aba encontrada: STARNAV TAURUS
# Procurando aba: STARNAV URSUS
# Aba encontrada: STARNAV URSUS
# Procurando aba: STARNAV VOLANS
# Aba encontrada: STARNAV VOLANS

# %%
ws = wb[aba]
print(ws)
# Out:
# <Worksheet "DELTA COMMANDER">

# %%
wb.save("SURVEY_CBO_teste.xlsx")
