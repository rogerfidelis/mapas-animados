# %%
import pandas as pd
import plotly.express as px
from gerar_mapa import BASE

# =========================
# ARQUIVO DE DADOS
# =========================

ARQUIVO = BASE / "dados" / "SURVEY_starnav_D1.xlsx"

# Lê todas as abas
abas = pd.read_excel(ARQUIVO, sheet_name=None)

# =========================
# GERA UM GRÁFICO POR ABA
# =========================

for nome_aba, df in abas.items():

    # Ignora a aba de posições
    if nome_aba.lower() == "posicoes":
        continue

    print(f"Gerando gráfico: {nome_aba}")

    status = (
        df["campo"]
        .dropna()
        .value_counts()
    )

    fig = px.pie(
        values=status.values,
        names=status.index,
        hole=0.60,
        title=f"Atendimento - {nome_aba}"
    )

    fig.update_traces(
        textposition="inside",
        textinfo="percent+label"
    )

    fig.update_layout(
        template="plotly_white",
        showlegend=True
    )

    nome_arquivo = (
        nome_aba.lower()
        .replace(" ", "_")
        .replace("á","a")
        .replace("é","e")
        .replace("í","i")
        .replace("ó","o")
        .replace("ú","u")
        .replace("ã","a")
        .replace("ç","c")
    )

    fig.write_html(
        BASE / "graficos" /"campo_atendimento"/ "starnav" / f"{nome_arquivo}.html",
        include_plotlyjs="cdn",
        full_html=False
    )

print("Gráficos gerados com sucesso!")
# Out:
# Gerando gráfico: STARNAV ANDROMEDA
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 61
#      44     fig.update_layout(
#      45         template="plotly_white",
#      46         showlegend=True
#      47     )
#      49     nome_arquivo = (
#      50         nome_aba.lower()
#      51         .replace(" ", "_")
#    (...)
#      58         .replace("ç","c")
#      59     )
# ---> 61     fig.write_html(
#      62         BASE / "graficos" /"campo_atendimento"/ "starnav" / f"{nome_arquivo}.html",
#      63         include_plotlyjs="cdn",
#      64         full_html=False
#      65     )
#      67 print("Gráficos gerados com sucesso!")
#
# File ~\Anaconda3\envs\geo_video\lib\site-packages\plotly\basedatatypes.py:3712, in BaseFigure.write_html(self, *args, **kwargs)
#    3609 """
#    3610 Write a figure to an HTML file representation
#    3611
#    (...)
# ...
